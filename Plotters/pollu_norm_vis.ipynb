# %%
# %load_ext autoreload
# %autoreload 2

import sys, pathlib
project_root = pathlib.Path("/Users/aya/github/WWDR")
if str(project_root / "Codex") not in sys.path:
    sys.path.append(str(project_root / "Codex"))

from Codex import pollu_norm_vis
pollu_norm_vis.main()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# INFO: Saved iteration plot to plots/pollu_norm/iterations/4h/normalized_diff_settler_iter245.png
# INFO: Saved iteration plot to plots/pollu_norm/iterations/4h/normalized_diff_settler_iter259.png
# INFO: Saved iteration plot to plots/pollu_norm/iterations/4h/normalized_diff_settler_iter273.png
# INFO: Saved iteration plot to plots/pollu_norm/iterations/4h/normalized_diff_settler_iter287.png
# INFO: Saved iteration plot to plots/pollu_norm/iterations/4h/normalized_diff_settler_iter301.png
# INFO: Saved iteration plot to plots/pollu_norm/iterations/4h/normalized_diff_settler_iter315.png
# INFO: Saved iteration plot to plots/pollu_norm/iterations/4h/normalized_diff_settler_iter329.png
# INFO: Saved iteration plot to plots/pollu_norm/iterations/4h/normalized_diff_settler_iter343.png
# INFO: Saved iteration plot to plots/pollu_norm/iterations/4h/normalized_diff_settler_iter357.png
# ...
